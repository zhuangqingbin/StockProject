# %%
import matplotlib
matplotlib.use('module://matplotlib_inline.backend_inline')
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import backtrader as bt
import backtrader.indicators as btind # 导入策略分析模块
import pandas as pd
import tushare as ts
import warnings
import datetime
warnings.filterwarnings("ignore")

# %%
# 引入自己开发的模块
from pathlib import Path
import sys
root = Path.cwd()
if not (root / 'common').exists():      # 如果当前目录没有 common/
    sys.path.insert(0, str(root.parent))  # 把父目录放到 import 路径最前

from common.utils import get_engine
from DataFetch.stock_basic import *

# %% [markdown]
# ### 从本地mysql取数据

# %%
engine = get_engine()

# %%
ts_code = '000001.SZ'
query = f"""
SELECT * FROM daily_kline
WHERE ts_code = '{ts_code}'
ORDER BY trade_date ASC
"""
df_sql1 = pd.read_sql(query, engine)
df_sql1['date'] = pd.to_datetime(df_sql1['trade_date'])

# %%
ts_code = '002594.SZ'
query = f"""
SELECT * FROM daily_kline
WHERE ts_code = '{ts_code}'
ORDER BY trade_date ASC
"""
df_sql2 = pd.read_sql(query, engine)
df_sql2['date'] = pd.to_datetime(df_sql2['trade_date'])

# %% [markdown]
# ### 从tushare取数据

# %%
# from DataFetch.stock_basic import *

# %%
# stock_daily = StockDailyFetch()
# stock_daily.fetch_data(name = "000001.SZ 数据", ts_code="000001.SZ", start_date="20100901", end_date = "20101230")
# df_ts000001 = stock_daily.data
# df_ts000001['date'] = pd.to_datetime(df_ts000001['trade_date'])

# %%
# stock_daily = StockDailyFetch()
# stock_daily.fetch_data(name = "600519.SH 数据", ts_code="600519.SH", start_date="20100901", end_date = "20101230")
# df_ts600519 = stock_daily.data
# df_ts600519['date'] = pd.to_datetime(df_ts600519['trade_date'])

# %% [markdown]
# ## 简单策略demo

# %%
class TS_Data(bt.feeds.PandasData):
    # 要添加的线 (初始 'close', 'low', 'high', 'open', 'volume', 'openinterest', 'datetime')
    lines = ('pre_close', 'change', 'amount', 'extra') 
    # 设置 line 在数据源上的列位置
    # -1 表示自动按列名匹配数据, None表示不存在（datetime则表示在index）, string直接写数据中的列名
    params = (
        ('fromdate', datetime.datetime(2022,4,1)),
        ('todate', datetime.datetime(2022,8,8)),
        ('nullvalue', 0.0),
        ('dtformat', ('%Y-%m-%d')),
        ('datetime', "date"),
        ('open', "open"),
        ('high', "high"),
        ('low', "low"),
        ('close', "close"),
        ('pre_close', "pre_close"),
        ('change', "change"),
        ('openinterest', "pct_chg"),
        ('volume', "vol"),
        ('amount', "amount"),
        ('extra', -1)
    )
    # def _load(self):
    #     # 调用原始的 _load 方法
    #     super()._load()

    #     # 添加你的自定义逻辑
    #     # _load方法是在每一个数据点被加载时调用的，所以你可以在这里添加你的自定义逻辑。
    #     # 你可以访问self.p.dataname来获取原始的Pandas DataFrame，然后从中提取你需要的数据。
    #     self.lines.extra[0] = self.p.dataname['extra'][self._idx]

    #     return True

# %%
class StockCommission(bt.CommInfoBase):
    params = (
        ('stocklike', True), # 指定为股票模式
        ('commtype', bt.CommInfoBase.COMM_PERC), # 使用百分比费用模式
        ('percabs', True), # commission 不以 % 为单位
        ('stamp_duty', 0.001), # 印花税默认为 0.1%
        ('commission', 0.0001), # 交易佣金默认为 0.01%
     ) 
    
    # 自定义费用计算公式
    def _getcommission(self, size, price, pseudoexec):
        if size > 0: # 买入时，只考虑佣金
            return abs(size) * price * self.p.commission
        elif size < 0: # 卖出时，同时考虑佣金和印花税
            return abs(size) * price * (self.p.commission + self.p.stamp_duty)
        else:
            return 0

# %%
# 初始化 交易
cerebro = bt.Cerebro()
# 设置初始资金
cerebro.broker.setcash(50000.0)
cerebro.broker.getcash() # 获取当前可用资金

# 设置交易费用
comminfo = StockCommission()                   
cerebro.broker.addcommissioninfo(comminfo)

# 通过调用 brokers 的 set_slippage_perc 方法设置百分比滑点
cerebro.broker.set_slippage_perc(perc=0.0001)



# data_ts_600519 = TS_Data(dataname=df_ts600519, fromdate=datetime.datetime(2010,9,1),
#                 todate=datetime.datetime(2010,12,30), nullvalue = None)
# data_ts_000001 = TS_Data(dataname=df_ts000001, fromdate=datetime.datetime(2010,9,1),
#                 todate=datetime.datetime(2010,12,30), nullvalue = None)

data_sql1 = TS_Data(dataname=df_sql1, fromdate=datetime.datetime(2025,1,1),todate=datetime.datetime(2025,8,8))
data_sql2 = TS_Data(dataname=df_sql2, fromdate=datetime.datetime(2025,1,1),todate=datetime.datetime(2025,8,8))
cerebro.adddata(data_sql1, name='000001')
cerebro.adddata(data_sql2, name='002594')

# %%
class TestStrategy(bt.Strategy):
    # self.data = self.datas[0]   self.dataX = self.datas[0]
    def __init__(self):
        self.dec = "="*8
        print("{dec} {text:^50s} {dec}".format(dec=self.dec, text="打印 self 策略本身的 lines"))
        print(self.lines.getlinealiases())
        print("{dec} {text:^50s} {dec}".format(dec=self.dec, text="打印 self.datas 第一个数据表格的 lines"))
        print(self.datas[0].lines.getlinealiases())
        print("{dec} {text:^50s} {dec}".format(dec=self.dec, text="打印 最后一天数据"))

        me1 = btind.EMA(self.datas[0].close, period=3)

        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=5)

        # Indicators for the plotting show
        bt.indicators.ExponentialMovingAverage(self.datas[0], period=25)
        bt.indicators.WeightedMovingAverage(self.datas[0], period=25,
                                            subplot=True)
        bt.indicators.StochasticSlow(self.datas[0])
        bt.indicators.MACDHisto(self.datas[0])
        rsi = bt.indicators.RSI(self.datas[0])
        bt.indicators.SmoothedMovingAverage(rsi, period=10)
        bt.indicators.ATR(self.datas[0], plot=False)

        

    def prenext(self):
        print("prenext ", bt.num2date(self.datas[0].datetime[0]))

    def nextstart(self):
        
        print("nextstart ", bt.num2date(self.datas[0].datetime[0]))
        self.next()
    
    def next(self):
        print("{dec} {text:^50s} {dec}".format(dec=self.dec, text="打印 当天数据"))

        print("date: {}, data1 close: {:.2f}, data2 close: {:.2f}. ".format(
                bt.num2date(self.datas[0].datetime[0]), self.datas[0].close[0], self.datas[1].close[0]))
        print('seen:', len(self.data), ' / total:', self.data.buflen())
        print('seen:', len(self.datas[0].close), ' / total:', self.datas[0].close.buflen())
        # print(self.datas[0].close[-1], "\nself.datas[0].lines.close.get(ago=0, size=2)", self.datas[0].lines.close.get(ago=0, size=2), 
        #       "\nself.datas[0].lines.close.get(ago=1, size=2)", self.datas[0].lines.close.get(ago=1, size=2),
        #       "\nself.datas[0].lines.close.get(size=3)", self.datas[0].lines.close.get(size=3),
        #       "\nself.datas[0].lines.close.get(ago=-1,size=3)", self.datas[0].lines.close.get(ago=-1,size=3))

# %%
cerebro.addstrategy(TestStrategy)
cerebro.run()
# Out:
# ========                打印 self 策略本身的 lines                 ========
# ('datetime',)
# ========            打印 self.datas 第一个数据表格的 lines            ========
# ('close', 'low', 'high', 'open', 'volume', 'openinterest', 'datetime', 'pre_close', 'change', 'amount', 'extra')
# ========                     打印 最后一天数据                      ========
# prenext  2025-01-02 00:00:00
# prenext  2025-01-03 00:00:00
# prenext  2025-01-06 00:00:00
# prenext  2025-01-07 00:00:00
# prenext  2025-01-08 00:00:00
# prenext  2025-01-09 00:00:00
# prenext  2025-01-10 00:00:00
# prenext  2025-01-13 00:00:00
# prenext  2025-01-14 00:00:00
# prenext  2025-01-15 00:00:00
# prenext  2025-01-16 00:00:00
# prenext  2025-01-17 00:00:00
# prenext  2025-01-20 00:00:00
# prenext  2025-01-21 00:00:00
# prenext  2025-01-22 00:00:00
# prenext  2025-01-23 00:00:00
# prenext  2025-01-24 00:00:00
# prenext  2025-01-27 00:00:00
# prenext  2025-02-05 00:00:00
# prenext  2025-02-06 00:00:00
# prenext  2025-02-07 00:00:00
# prenext  2025-02-10 00:00:00
# prenext  2025-02-11 00:00:00
# prenext  2025-02-12 00:00:00
# prenext  2025-02-13 00:00:00
# prenext  2025-02-14 00:00:00
# prenext  2025-02-17 00:00:00
# prenext  2025-02-18 00:00:00
# prenext  2025-02-19 00:00:00
# prenext  2025-02-20 00:00:00
# prenext  2025-02-21 00:00:00
# prenext  2025-02-24 00:00:00
# prenext  2025-02-25 00:00:00
# nextstart  2025-02-26 00:00:00
# ========                      打印 当天数据                       ========
# date: 2025-02-26 00:00:00, data1 close: 11.52, data2 close: 372.10.
# seen: 34  / total: 146
# seen: 34  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-02-27 00:00:00, data1 close: 11.62, data2 close: 375.50.
# seen: 35  / total: 146
# seen: 35  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-02-28 00:00:00, data1 close: 11.53, data2 close: 361.82.
# seen: 36  / total: 146
# seen: 36  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-03 00:00:00, data1 close: 11.51, data2 close: 360.21.
# seen: 37  / total: 146
# seen: 37  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-04 00:00:00, data1 close: 11.51, data2 close: 344.84.
# seen: 38  / total: 146
# seen: 38  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-05 00:00:00, data1 close: 11.66, data2 close: 353.96.
# seen: 39  / total: 146
# seen: 39  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-06 00:00:00, data1 close: 11.63, data2 close: 358.93.
# seen: 40  / total: 146
# seen: 40  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-07 00:00:00, data1 close: 11.67, data2 close: 356.40.
# seen: 41  / total: 146
# seen: 41  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-10 00:00:00, data1 close: 11.59, data2 close: 351.00.
# seen: 42  / total: 146
# seen: 42  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-11 00:00:00, data1 close: 11.61, data2 close: 350.38.
# seen: 43  / total: 146
# seen: 43  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-12 00:00:00, data1 close: 11.85, data2 close: 351.00.
# seen: 44  / total: 146
# seen: 44  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-13 00:00:00, data1 close: 11.84, data2 close: 354.50.
# seen: 45  / total: 146
# seen: 45  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-14 00:00:00, data1 close: 11.97, data2 close: 375.94.
# seen: 46  / total: 146
# seen: 46  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-17 00:00:00, data1 close: 11.50, data2 close: 380.25.
# seen: 47  / total: 146
# seen: 47  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-18 00:00:00, data1 close: 11.49, data2 close: 384.57.
# seen: 48  / total: 146
# seen: 48  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-19 00:00:00, data1 close: 11.52, data2 close: 397.07.
# seen: 49  / total: 146
# seen: 49  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-20 00:00:00, data1 close: 11.49, data2 close: 399.99.
# seen: 50  / total: 146
# seen: 50  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-21 00:00:00, data1 close: 11.42, data2 close: 372.00.
# seen: 51  / total: 146
# seen: 51  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-24 00:00:00, data1 close: 11.38, data2 close: 375.36.
# seen: 52  / total: 146
# seen: 52  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-25 00:00:00, data1 close: 11.43, data2 close: 369.59.
# seen: 53  / total: 146
# seen: 53  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-26 00:00:00, data1 close: 11.38, data2 close: 376.01.
# seen: 54  / total: 146
# seen: 54  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-27 00:00:00, data1 close: 11.39, data2 close: 386.50.
# seen: 55  / total: 146
# seen: 55  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-28 00:00:00, data1 close: 11.35, data2 close: 382.50.
# seen: 56  / total: 146
# seen: 56  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-03-31 00:00:00, data1 close: 11.26, data2 close: 374.90.
# seen: 57  / total: 146
# seen: 57  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-01 00:00:00, data1 close: 11.27, data2 close: 365.50.
# seen: 58  / total: 146
# seen: 58  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-02 00:00:00, data1 close: 11.37, data2 close: 360.50.
# seen: 59  / total: 146
# seen: 59  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-03 00:00:00, data1 close: 11.34, data2 close: 357.51.
# seen: 60  / total: 146
# seen: 60  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-07 00:00:00, data1 close: 10.70, data2 close: 321.76.
# seen: 61  / total: 146
# seen: 61  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-08 00:00:00, data1 close: 10.82, data2 close: 327.51.
# seen: 62  / total: 146
# seen: 62  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-09 00:00:00, data1 close: 10.80, data2 close: 324.60.
# seen: 63  / total: 146
# seen: 63  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-10 00:00:00, data1 close: 10.90, data2 close: 336.40.
# seen: 64  / total: 146
# seen: 64  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-11 00:00:00, data1 close: 10.89, data2 close: 354.98.
# seen: 65  / total: 146
# seen: 65  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-14 00:00:00, data1 close: 10.93, data2 close: 359.00.
# seen: 66  / total: 146
# seen: 66  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-15 00:00:00, data1 close: 10.95, data2 close: 359.97.
# seen: 67  / total: 146
# seen: 67  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-16 00:00:00, data1 close: 11.00, data2 close: 352.15.
# seen: 68  / total: 146
# seen: 68  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-17 00:00:00, data1 close: 11.06, data2 close: 349.68.
# seen: 69  / total: 146
# seen: 69  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-18 00:00:00, data1 close: 11.18, data2 close: 346.00.
# seen: 70  / total: 146
# seen: 70  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-21 00:00:00, data1 close: 11.02, data2 close: 348.76.
# seen: 71  / total: 146
# seen: 71  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-22 00:00:00, data1 close: 11.04, data2 close: 354.84.
# seen: 72  / total: 146
# seen: 72  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-23 00:00:00, data1 close: 11.01, data2 close: 371.99.
# seen: 73  / total: 146
# seen: 73  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-24 00:00:00, data1 close: 11.03, data2 close: 366.00.
# seen: 74  / total: 146
# seen: 74  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-25 00:00:00, data1 close: 11.01, data2 close: 370.83.
# seen: 75  / total: 146
# seen: 75  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-28 00:00:00, data1 close: 11.00, data2 close: 360.00.
# seen: 76  / total: 146
# seen: 76  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-29 00:00:00, data1 close: 10.98, data2 close: 355.00.
# seen: 77  / total: 146
# seen: 77  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-04-30 00:00:00, data1 close: 10.91, data2 close: 353.09.
# seen: 78  / total: 146
# seen: 78  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-06 00:00:00, data1 close: 10.96, data2 close: 359.96.
# seen: 79  / total: 146
# seen: 79  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-07 00:00:00, data1 close: 11.03, data2 close: 359.20.
# seen: 80  / total: 146
# seen: 80  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-08 00:00:00, data1 close: 11.08, data2 close: 359.28.
# seen: 81  / total: 146
# seen: 81  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-09 00:00:00, data1 close: 11.15, data2 close: 363.22.
# seen: 82  / total: 146
# seen: 82  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-12 00:00:00, data1 close: 11.16, data2 close: 370.28.
# seen: 83  / total: 146
# seen: 83  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-13 00:00:00, data1 close: 11.29, data2 close: 366.50.
# seen: 84  / total: 146
# seen: 84  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-14 00:00:00, data1 close: 11.43, data2 close: 373.10.
# seen: 85  / total: 146
# seen: 85  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-15 00:00:00, data1 close: 11.39, data2 close: 376.80.
# seen: 86  / total: 146
# seen: 86  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-16 00:00:00, data1 close: 11.38, data2 close: 389.17.
# seen: 87  / total: 146
# seen: 87  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-19 00:00:00, data1 close: 11.37, data2 close: 382.81.
# seen: 88  / total: 146
# seen: 88  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-20 00:00:00, data1 close: 11.39, data2 close: 394.80.
# seen: 89  / total: 146
# seen: 89  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-21 00:00:00, data1 close: 11.48, data2 close: 400.00.
# seen: 90  / total: 146
# seen: 90  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-22 00:00:00, data1 close: 11.55, data2 close: 398.80.
# seen: 91  / total: 146
# seen: 91  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-23 00:00:00, data1 close: 11.46, data2 close: 405.00.
# seen: 92  / total: 146
# seen: 92  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-26 00:00:00, data1 close: 11.42, data2 close: 381.00.
# seen: 93  / total: 146
# seen: 93  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-27 00:00:00, data1 close: 11.49, data2 close: 372.41.
# seen: 94  / total: 146
# seen: 94  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-28 00:00:00, data1 close: 11.53, data2 close: 362.88.
# seen: 95  / total: 146
# seen: 95  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-29 00:00:00, data1 close: 11.46, data2 close: 361.13.
# seen: 96  / total: 146
# seen: 96  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-05-30 00:00:00, data1 close: 11.56, data2 close: 352.30.
# seen: 97  / total: 146
# seen: 97  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-03 00:00:00, data1 close: 11.81, data2 close: 356.00.
# seen: 98  / total: 146
# seen: 98  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-04 00:00:00, data1 close: 11.84, data2 close: 360.52.
# seen: 99  / total: 146
# seen: 99  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-05 00:00:00, data1 close: 11.67, data2 close: 360.75.
# seen: 100  / total: 146
# seen: 100  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-06 00:00:00, data1 close: 11.70, data2 close: 359.96.
# seen: 101  / total: 146
# seen: 101  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-09 00:00:00, data1 close: 11.71, data2 close: 348.14.
# seen: 102  / total: 146
# seen: 102  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-10 00:00:00, data1 close: 11.81, data2 close: 353.13.
# seen: 103  / total: 146
# seen: 103  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-11 00:00:00, data1 close: 11.85, data2 close: 361.99.
# seen: 104  / total: 146
# seen: 104  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-12 00:00:00, data1 close: 11.68, data2 close: 353.24.
# seen: 105  / total: 146
# seen: 105  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-13 00:00:00, data1 close: 11.58, data2 close: 346.00.
# seen: 106  / total: 146
# seen: 106  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-16 00:00:00, data1 close: 11.79, data2 close: 344.43.
# seen: 107  / total: 146
# seen: 107  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-17 00:00:00, data1 close: 11.76, data2 close: 343.74.
# seen: 108  / total: 146
# seen: 108  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-18 00:00:00, data1 close: 11.77, data2 close: 346.95.
# seen: 109  / total: 146
# seen: 109  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-19 00:00:00, data1 close: 11.70, data2 close: 340.50.
# seen: 110  / total: 146
# seen: 110  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-20 00:00:00, data1 close: 11.84, data2 close: 340.25.
# seen: 111  / total: 146
# seen: 111  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-23 00:00:00, data1 close: 11.93, data2 close: 338.20.
# seen: 112  / total: 146
# seen: 112  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-24 00:00:00, data1 close: 11.93, data2 close: 343.38.
# seen: 113  / total: 146
# seen: 113  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-25 00:00:00, data1 close: 12.06, data2 close: 349.27.
# seen: 114  / total: 146
# seen: 114  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-26 00:00:00, data1 close: 12.41, data2 close: 337.44.
# seen: 115  / total: 146
# seen: 115  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-27 00:00:00, data1 close: 12.20, data2 close: 334.24.
# seen: 116  / total: 146
# seen: 116  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-06-30 00:00:00, data1 close: 12.07, data2 close: 331.91.
# seen: 117  / total: 146
# seen: 117  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-01 00:00:00, data1 close: 12.30, data2 close: 331.34.
# seen: 118  / total: 146
# seen: 118  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-02 00:00:00, data1 close: 12.32, data2 close: 330.66.
# seen: 119  / total: 146
# seen: 119  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-03 00:00:00, data1 close: 12.35, data2 close: 334.56.
# seen: 120  / total: 146
# seen: 120  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-04 00:00:00, data1 close: 12.60, data2 close: 331.00.
# seen: 121  / total: 146
# seen: 121  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-07 00:00:00, data1 close: 12.78, data2 close: 328.59.
# seen: 122  / total: 146
# seen: 122  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-08 00:00:00, data1 close: 12.69, data2 close: 326.88.
# seen: 123  / total: 146
# seen: 123  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-09 00:00:00, data1 close: 12.84, data2 close: 325.80.
# seen: 124  / total: 146
# seen: 124  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-10 00:00:00, data1 close: 13.18, data2 close: 321.23.
# seen: 125  / total: 146
# seen: 125  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-11 00:00:00, data1 close: 12.91, data2 close: 323.91.
# seen: 126  / total: 146
# seen: 126  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-14 00:00:00, data1 close: 12.98, data2 close: 318.49.
# seen: 127  / total: 146
# seen: 127  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-15 00:00:00, data1 close: 12.73, data2 close: 323.05.
# seen: 128  / total: 146
# seen: 128  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-16 00:00:00, data1 close: 12.64, data2 close: 323.72.
# seen: 129  / total: 146
# seen: 129  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-17 00:00:00, data1 close: 12.59, data2 close: 328.02.
# seen: 130  / total: 146
# seen: 130  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-18 00:00:00, data1 close: 12.70, data2 close: 329.11.
# seen: 131  / total: 146
# seen: 131  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-21 00:00:00, data1 close: 12.61, data2 close: 334.12.
# seen: 132  / total: 146
# seen: 132  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-22 00:00:00, data1 close: 12.49, data2 close: 341.69.
# seen: 133  / total: 146
# seen: 133  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-23 00:00:00, data1 close: 12.53, data2 close: 338.07.
# seen: 134  / total: 146
# seen: 134  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-24 00:00:00, data1 close: 12.35, data2 close: 342.72.
# seen: 135  / total: 146
# seen: 135  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-25 00:00:00, data1 close: 12.35, data2 close: 337.93.
# seen: 136  / total: 146
# seen: 136  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-28 00:00:00, data1 close: 12.46, data2 close: 337.00.
# seen: 137  / total: 146
# seen: 137  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-29 00:00:00, data1 close: 12.34, data2 close: 111.42.
# seen: 138  / total: 146
# seen: 138  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-30 00:00:00, data1 close: 12.49, data2 close: 108.70.
# seen: 139  / total: 146
# seen: 139  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-07-31 00:00:00, data1 close: 12.23, data2 close: 105.24.
# seen: 140  / total: 146
# seen: 140  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-08-01 00:00:00, data1 close: 12.28, data2 close: 105.80.
# seen: 141  / total: 146
# seen: 141  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-08-04 00:00:00, data1 close: 12.30, data2 close: 104.88.
# seen: 142  / total: 146
# seen: 142  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-08-05 00:00:00, data1 close: 12.47, data2 close: 104.86.
# seen: 143  / total: 146
# seen: 143  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-08-06 00:00:00, data1 close: 12.46, data2 close: 104.35.
# seen: 144  / total: 146
# seen: 144  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-08-07 00:00:00, data1 close: 12.47, data2 close: 105.33.
# seen: 145  / total: 146
# seen: 145  / total: 146
# ========                      打印 当天数据                       ========
# date: 2025-08-08 00:00:00, data1 close: 12.40, data2 close: 103.93.
# seen: 146  / total: 146
# seen: 146  / total: 146

# %%
class My_MACD(bt.Indicator):
    lines = ('macd', 'signal', 'histo')
    params = (('period_me1',12),
              ('period_me2', 26),
              ('period_signal', 9),)

    def __init__(self):
        me1 = btind.EMA(self.datas[0].close, period=self.p.period_me1)
        me2 = btind.EMA(self.datas[0].close, period=self.p.period_me2)
        self.l.macd = me1 - me2
        self.l.signal = btind.EMA(self.l.macd, period=self.p.period_signal)
        self.l.histo = self.l.macd - self.l.signal

class TestStrategy1(bt.Strategy):
    # self.data = self.datas[0]   self.dataX = self.datas[0]
    def __init__(self):
        self.dec = "="*8
        print("{dec} {text:^50s} {dec}".format(dec=self.dec, text="打印 self 策略本身的 lines"))
        print(self.lines.getlinealiases())
        print("{dec} {text:^50s} {dec}".format(dec=self.dec, text="打印 self.datas 第一个数据表格的 lines"))
        print(self.datas[0].lines.getlinealiases())
        print("{dec} {text:^50s} {dec}".format(dec=self.dec, text="打印 最后一天数据"))
        print(bt.num2date(self.datas[0].datetime[0]), end = ':\t')
        print(self.datas[0].close[0], end = "\t")
        print(self.datas[0].openinterest[0])

        # 
        self.ma3 = btind.SimpleMovingAverage(self.datas[0].close, period=3)
        self.ma5 = btind.SimpleMovingAverage(self.datas[0].close, period=5)
        self.macd = My_MACD(period_me1=3,period_me2=5,period_signal=2)
        
    def next(self):
        print("{dec} {text:^50s} {dec}".format(dec=self.dec, text="打印 当天数据"))
        # print("date: {}, close: {:.2f}, ma3: {:.2f}, ma5: {:.2f}, macd: {:.2f}, signal: {:.2f}, histo: {:.2f}. ".format(
        #         bt.num2date(self.datas[0].datetime[0]), self.datas[0].close[0], self.ma3[0], self.ma5[0], 
        #         self.macd.macd[0], self.macd.signal[0], self.macd.histo[0]))
        print("date: {}, data1 close: {:.2f}, data2 close: {:.2f}. ".format(
                bt.num2date(self.datas[0].datetime[0]), self.datas[0].close[0], self.datas[1].close[0]))
        if self.ma5 > self.ma3:
            print("买买买")

# %%
# 初始化 交易
cerebro = bt.Cerebro()
# 设置初始资金
cerebro.broker.setcash(50000.0)
cerebro.broker.getcash() # 获取当前可用资金

# 设置交易费用
comminfo = StockCommission()                   
cerebro.broker.addcommissioninfo(comminfo)

# 通过调用 brokers 的 set_slippage_perc 方法设置百分比滑点
cerebro.broker.set_slippage_perc(perc=0.0001)



# data_ts_600519 = TS_Data(dataname=df_ts600519, fromdate=datetime.datetime(2010,9,1),
#                 todate=datetime.datetime(2010,12,30), nullvalue = None)
# data_ts_000001 = TS_Data(dataname=df_ts000001, fromdate=datetime.datetime(2010,9,1),
#                 todate=datetime.datetime(2010,12,30), nullvalue = None)

data_sql1 = TS_Data(dataname=df_sql1, fromdate=datetime.datetime(2025,1,1),todate=datetime.datetime(2025,8,8))
data_sql2 = TS_Data(dataname=df_sql2, fromdate=datetime.datetime(2025,1,1),todate=datetime.datetime(2025,8,8))
cerebro.adddata(data_sql1, name='000001')
cerebro.adddata(data_sql2, name='002594')

# %%
cerebro.addstrategy(TestStrategy1)
cerebro.run()
# Out:
# ========                打印 self 策略本身的 lines                 ========
# ('datetime',)
# ========            打印 self.datas 第一个数据表格的 lines            ========
# ('close', 'low', 'high', 'open', 'volume', 'openinterest', 'datetime', 'pre_close', 'change', 'amount', 'extra')
# ========                     打印 最后一天数据                      ========
# 2025-08-08 00:00:00:	12.4	-0.5613
# ========                      打印 当天数据                       ========
# date: 2025-01-09 00:00:00, data1 close: 11.40, data2 close: 269.39.
# ========                      打印 当天数据                       ========
# date: 2025-01-10 00:00:00, data1 close: 11.30, data2 close: 266.02.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-01-13 00:00:00, data1 close: 11.20, data2 close: 266.00.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-01-14 00:00:00, data1 close: 11.38, data2 close: 276.30.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-01-15 00:00:00, data1 close: 11.48, data2 close: 274.69.
# ========                      打印 当天数据                       ========
# date: 2025-01-16 00:00:00, data1 close: 11.57, data2 close: 272.76.
# ========                      打印 当天数据                       ========
# date: 2025-01-17 00:00:00, data1 close: 11.45, data2 close: 276.60.
# ========                      打印 当天数据                       ========
# date: 2025-01-20 00:00:00, data1 close: 11.42, data2 close: 284.43.
# ========                      打印 当天数据                       ========
# date: 2025-01-21 00:00:00, data1 close: 11.33, data2 close: 286.05.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-01-22 00:00:00, data1 close: 11.09, data2 close: 282.50.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-01-23 00:00:00, data1 close: 11.32, data2 close: 277.11.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-01-24 00:00:00, data1 close: 11.34, data2 close: 279.08.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-01-27 00:00:00, data1 close: 11.47, data2 close: 274.50.
# ========                      打印 当天数据                       ========
# date: 2025-02-05 00:00:00, data1 close: 11.37, data2 close: 282.80.
# ========                      打印 当天数据                       ========
# date: 2025-02-06 00:00:00, data1 close: 11.36, data2 close: 311.08.
# ========                      打印 当天数据                       ========
# date: 2025-02-07 00:00:00, data1 close: 11.38, data2 close: 326.90.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-02-10 00:00:00, data1 close: 11.43, data2 close: 330.13.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-02-11 00:00:00, data1 close: 11.42, data2 close: 329.90.
# ========                      打印 当天数据                       ========
# date: 2025-02-12 00:00:00, data1 close: 11.42, data2 close: 345.05.
# ========                      打印 当天数据                       ========
# date: 2025-02-13 00:00:00, data1 close: 11.50, data2 close: 341.30.
# ========                      打印 当天数据                       ========
# date: 2025-02-14 00:00:00, data1 close: 11.55, data2 close: 356.05.
# ========                      打印 当天数据                       ========
# date: 2025-02-17 00:00:00, data1 close: 11.78, data2 close: 348.50.
# ========                      打印 当天数据                       ========
# date: 2025-02-18 00:00:00, data1 close: 11.81, data2 close: 356.22.
# ========                      打印 当天数据                       ========
# date: 2025-02-19 00:00:00, data1 close: 11.71, data2 close: 358.50.
# ========                      打印 当天数据                       ========
# date: 2025-02-20 00:00:00, data1 close: 11.66, data2 close: 362.78.
# ========                      打印 当天数据                       ========
# date: 2025-02-21 00:00:00, data1 close: 11.64, data2 close: 383.00.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-02-24 00:00:00, data1 close: 11.59, data2 close: 376.28.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-02-25 00:00:00, data1 close: 11.47, data2 close: 372.49.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-02-26 00:00:00, data1 close: 11.52, data2 close: 372.10.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-02-27 00:00:00, data1 close: 11.62, data2 close: 375.50.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-02-28 00:00:00, data1 close: 11.53, data2 close: 361.82.
# ========                      打印 当天数据                       ========
# date: 2025-03-03 00:00:00, data1 close: 11.51, data2 close: 360.21.
# ========                      打印 当天数据                       ========
# date: 2025-03-04 00:00:00, data1 close: 11.51, data2 close: 344.84.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-03-05 00:00:00, data1 close: 11.66, data2 close: 353.96.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-03-06 00:00:00, data1 close: 11.63, data2 close: 358.93.
# ========                      打印 当天数据                       ========
# date: 2025-03-07 00:00:00, data1 close: 11.67, data2 close: 356.40.
# ========                      打印 当天数据                       ========
# date: 2025-03-10 00:00:00, data1 close: 11.59, data2 close: 351.00.
# ========                      打印 当天数据                       ========
# date: 2025-03-11 00:00:00, data1 close: 11.61, data2 close: 350.38.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-03-12 00:00:00, data1 close: 11.85, data2 close: 351.00.
# ========                      打印 当天数据                       ========
# date: 2025-03-13 00:00:00, data1 close: 11.84, data2 close: 354.50.
# ========                      打印 当天数据                       ========
# date: 2025-03-14 00:00:00, data1 close: 11.97, data2 close: 375.94.
# ========                      打印 当天数据                       ========
# date: 2025-03-17 00:00:00, data1 close: 11.50, data2 close: 380.25.
# ========                      打印 当天数据                       ========
# date: 2025-03-18 00:00:00, data1 close: 11.49, data2 close: 384.57.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-03-19 00:00:00, data1 close: 11.52, data2 close: 397.07.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-03-20 00:00:00, data1 close: 11.49, data2 close: 399.99.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-03-21 00:00:00, data1 close: 11.42, data2 close: 372.00.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-03-24 00:00:00, data1 close: 11.38, data2 close: 375.36.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-03-25 00:00:00, data1 close: 11.43, data2 close: 369.59.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-03-26 00:00:00, data1 close: 11.38, data2 close: 376.01.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-03-27 00:00:00, data1 close: 11.39, data2 close: 386.50.
# ========                      打印 当天数据                       ========
# date: 2025-03-28 00:00:00, data1 close: 11.35, data2 close: 382.50.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-03-31 00:00:00, data1 close: 11.26, data2 close: 374.90.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-01 00:00:00, data1 close: 11.27, data2 close: 365.50.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-02 00:00:00, data1 close: 11.37, data2 close: 360.50.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-03 00:00:00, data1 close: 11.34, data2 close: 357.51.
# ========                      打印 当天数据                       ========
# date: 2025-04-07 00:00:00, data1 close: 10.70, data2 close: 321.76.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-08 00:00:00, data1 close: 10.82, data2 close: 327.51.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-09 00:00:00, data1 close: 10.80, data2 close: 324.60.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-10 00:00:00, data1 close: 10.90, data2 close: 336.40.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-11 00:00:00, data1 close: 10.89, data2 close: 354.98.
# ========                      打印 当天数据                       ========
# date: 2025-04-14 00:00:00, data1 close: 10.93, data2 close: 359.00.
# ========                      打印 当天数据                       ========
# date: 2025-04-15 00:00:00, data1 close: 10.95, data2 close: 359.97.
# ========                      打印 当天数据                       ========
# date: 2025-04-16 00:00:00, data1 close: 11.00, data2 close: 352.15.
# ========                      打印 当天数据                       ========
# date: 2025-04-17 00:00:00, data1 close: 11.06, data2 close: 349.68.
# ========                      打印 当天数据                       ========
# date: 2025-04-18 00:00:00, data1 close: 11.18, data2 close: 346.00.
# ========                      打印 当天数据                       ========
# date: 2025-04-21 00:00:00, data1 close: 11.02, data2 close: 348.76.
# ========                      打印 当天数据                       ========
# date: 2025-04-22 00:00:00, data1 close: 11.04, data2 close: 354.84.
# ========                      打印 当天数据                       ========
# date: 2025-04-23 00:00:00, data1 close: 11.01, data2 close: 371.99.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-24 00:00:00, data1 close: 11.03, data2 close: 366.00.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-25 00:00:00, data1 close: 11.01, data2 close: 370.83.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-28 00:00:00, data1 close: 11.00, data2 close: 360.00.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-29 00:00:00, data1 close: 10.98, data2 close: 355.00.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-04-30 00:00:00, data1 close: 10.91, data2 close: 353.09.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-05-06 00:00:00, data1 close: 10.96, data2 close: 359.96.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-05-07 00:00:00, data1 close: 11.03, data2 close: 359.20.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-05-08 00:00:00, data1 close: 11.08, data2 close: 359.28.
# ========                      打印 当天数据                       ========
# date: 2025-05-09 00:00:00, data1 close: 11.15, data2 close: 363.22.
# ========                      打印 当天数据                       ========
# date: 2025-05-12 00:00:00, data1 close: 11.16, data2 close: 370.28.
# ========                      打印 当天数据                       ========
# date: 2025-05-13 00:00:00, data1 close: 11.29, data2 close: 366.50.
# ========                      打印 当天数据                       ========
# date: 2025-05-14 00:00:00, data1 close: 11.43, data2 close: 373.10.
# ========                      打印 当天数据                       ========
# date: 2025-05-15 00:00:00, data1 close: 11.39, data2 close: 376.80.
# ========                      打印 当天数据                       ========
# date: 2025-05-16 00:00:00, data1 close: 11.38, data2 close: 389.17.
# ========                      打印 当天数据                       ========
# date: 2025-05-19 00:00:00, data1 close: 11.37, data2 close: 382.81.
# ========                      打印 当天数据                       ========
# date: 2025-05-20 00:00:00, data1 close: 11.39, data2 close: 394.80.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-05-21 00:00:00, data1 close: 11.48, data2 close: 400.00.
# ========                      打印 当天数据                       ========
# date: 2025-05-22 00:00:00, data1 close: 11.55, data2 close: 398.80.
# ========                      打印 当天数据                       ========
# date: 2025-05-23 00:00:00, data1 close: 11.46, data2 close: 405.00.
# ========                      打印 当天数据                       ========
# date: 2025-05-26 00:00:00, data1 close: 11.42, data2 close: 381.00.
# ========                      打印 当天数据                       ========
# date: 2025-05-27 00:00:00, data1 close: 11.49, data2 close: 372.41.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-05-28 00:00:00, data1 close: 11.53, data2 close: 362.88.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-05-29 00:00:00, data1 close: 11.46, data2 close: 361.13.
# ========                      打印 当天数据                       ========
# date: 2025-05-30 00:00:00, data1 close: 11.56, data2 close: 352.30.
# ========                      打印 当天数据                       ========
# date: 2025-06-03 00:00:00, data1 close: 11.81, data2 close: 356.00.
# ========                      打印 当天数据                       ========
# date: 2025-06-04 00:00:00, data1 close: 11.84, data2 close: 360.52.
# ========                      打印 当天数据                       ========
# date: 2025-06-05 00:00:00, data1 close: 11.67, data2 close: 360.75.
# ========                      打印 当天数据                       ========
# date: 2025-06-06 00:00:00, data1 close: 11.70, data2 close: 359.96.
# ========                      打印 当天数据                       ========
# date: 2025-06-09 00:00:00, data1 close: 11.71, data2 close: 348.14.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-06-10 00:00:00, data1 close: 11.81, data2 close: 353.13.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-06-11 00:00:00, data1 close: 11.85, data2 close: 361.99.
# ========                      打印 当天数据                       ========
# date: 2025-06-12 00:00:00, data1 close: 11.68, data2 close: 353.24.
# ========                      打印 当天数据                       ========
# date: 2025-06-13 00:00:00, data1 close: 11.58, data2 close: 346.00.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-06-16 00:00:00, data1 close: 11.79, data2 close: 344.43.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-06-17 00:00:00, data1 close: 11.76, data2 close: 343.74.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-06-18 00:00:00, data1 close: 11.77, data2 close: 346.95.
# ========                      打印 当天数据                       ========
# date: 2025-06-19 00:00:00, data1 close: 11.70, data2 close: 340.50.
# ========                      打印 当天数据                       ========
# date: 2025-06-20 00:00:00, data1 close: 11.84, data2 close: 340.25.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-06-23 00:00:00, data1 close: 11.93, data2 close: 338.20.
# ========                      打印 当天数据                       ========
# date: 2025-06-24 00:00:00, data1 close: 11.93, data2 close: 343.38.
# ========                      打印 当天数据                       ========
# date: 2025-06-25 00:00:00, data1 close: 12.06, data2 close: 349.27.
# ========                      打印 当天数据                       ========
# date: 2025-06-26 00:00:00, data1 close: 12.41, data2 close: 337.44.
# ========                      打印 当天数据                       ========
# date: 2025-06-27 00:00:00, data1 close: 12.20, data2 close: 334.24.
# ========                      打印 当天数据                       ========
# date: 2025-06-30 00:00:00, data1 close: 12.07, data2 close: 331.91.
# ========                      打印 当天数据                       ========
# date: 2025-07-01 00:00:00, data1 close: 12.30, data2 close: 331.34.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-02 00:00:00, data1 close: 12.32, data2 close: 330.66.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-03 00:00:00, data1 close: 12.35, data2 close: 334.56.
# ========                      打印 当天数据                       ========
# date: 2025-07-04 00:00:00, data1 close: 12.60, data2 close: 331.00.
# ========                      打印 当天数据                       ========
# date: 2025-07-07 00:00:00, data1 close: 12.78, data2 close: 328.59.
# ========                      打印 当天数据                       ========
# date: 2025-07-08 00:00:00, data1 close: 12.69, data2 close: 326.88.
# ========                      打印 当天数据                       ========
# date: 2025-07-09 00:00:00, data1 close: 12.84, data2 close: 325.80.
# ========                      打印 当天数据                       ========
# date: 2025-07-10 00:00:00, data1 close: 13.18, data2 close: 321.23.
# ========                      打印 当天数据                       ========
# date: 2025-07-11 00:00:00, data1 close: 12.91, data2 close: 323.91.
# ========                      打印 当天数据                       ========
# date: 2025-07-14 00:00:00, data1 close: 12.98, data2 close: 318.49.
# ========                      打印 当天数据                       ========
# date: 2025-07-15 00:00:00, data1 close: 12.73, data2 close: 323.05.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-16 00:00:00, data1 close: 12.64, data2 close: 323.72.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-17 00:00:00, data1 close: 12.59, data2 close: 328.02.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-18 00:00:00, data1 close: 12.70, data2 close: 329.11.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-21 00:00:00, data1 close: 12.61, data2 close: 334.12.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-22 00:00:00, data1 close: 12.49, data2 close: 341.69.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-23 00:00:00, data1 close: 12.53, data2 close: 338.07.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-24 00:00:00, data1 close: 12.35, data2 close: 342.72.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-25 00:00:00, data1 close: 12.35, data2 close: 337.93.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-28 00:00:00, data1 close: 12.46, data2 close: 337.00.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-29 00:00:00, data1 close: 12.34, data2 close: 111.42.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-07-30 00:00:00, data1 close: 12.49, data2 close: 108.70.
# ========                      打印 当天数据                       ========
# date: 2025-07-31 00:00:00, data1 close: 12.23, data2 close: 105.24.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-08-01 00:00:00, data1 close: 12.28, data2 close: 105.80.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-08-04 00:00:00, data1 close: 12.30, data2 close: 104.88.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-08-05 00:00:00, data1 close: 12.47, data2 close: 104.86.
# 买买买
# ========                      打印 当天数据                       ========
# date: 2025-08-06 00:00:00, data1 close: 12.46, data2 close: 104.35.
# ========                      打印 当天数据                       ========
# date: 2025-08-07 00:00:00, data1 close: 12.47, data2 close: 105.33.
# ========                      打印 当天数据                       ========
# date: 2025-08-08 00:00:00, data1 close: 12.40, data2 close: 103.93.

# %%
# 这是典型的 JupyterLab 4.x + matplotlib 后端 不匹配导致的前端 JS 报错。
# cerebro.plot() 在某些环境里会尝试用 “notebook/nbagg” 这种老前端（需要浏览器里有全局 IPython 对象），
# 而 JupyterLab 4.4.6 默认不再提供这个全局对象，所以就出现了 Javascript Error: IPython is not defined。
figs = cerebro.plot(iplot=False) 
plt.show()
# Out:
# 2025-08-16 11:37:53.290 Python[53832:16110441] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-08-16 11:37:53.290 Python[53832:16110441] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 4
#       1 # 这是典型的 JupyterLab 4.x + matplotlib 后端 不匹配导致的前端 JS 报错。
#       2 # cerebro.plot() 在某些环境里会尝试用 “notebook/nbagg” 这种老前端（需要浏览器里有全局 IPython 对象），
#       3 # 而 JupyterLab 4.4.6 默认不再提供这个全局对象，所以就出现了 Javascript Error: IPython is not defined。
# ----> 4 figs = cerebro.plot(iplot=False)
#       5 plt.show()
#
# File ~/Library/Python/3.9/lib/python/site-packages/backtrader/cerebro.py:1001, in Cerebro.plot(self, plotter, numfigs, iplot, start, end, width, height, dpi, tight, use, **kwargs)
#     997         # pfillers=pfillers2)
#     999         figs.append(rfig)
# -> 1001     plotter.show()
#    1003 return figs
#
# File ~/Library/Python/3.9/lib/python/site-packages/backtrader/plot/plot.py:821, in Plot_OldSync.show(self)
#     820 def show(self):
# --> 821     self.mpyplot.show()
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/pyplot.py:612, in show(*args, **kwargs)
#     568 """
#     569 Display all open figures.
#     570
#    (...)
#     609 explicitly there.
#     610 """
#     611 _warn_if_gui_out_of_main_thread()
# --> 612 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/backend_bases.py:3553, in _Backend.show(cls, block)
#    3551     block = not ipython_pylab and not is_interactive()
#    3552 if block:
# -> 3553     cls.mainloop()
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/backends/backend_macosx.py:179, in FigureManagerMac.start_main_loop(cls)
#     175 @classmethod
#     176 def start_main_loop(cls):
#     177     # Set up a SIGINT handler to allow terminating a plot via CTRL-C.
#     178     with _allow_interrupt_macos():
# --> 179         _macosx.show()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:124, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     122 if type is None:
#     123     try:
# --> 124         next(self.gen)
#     125     except StopIteration:
#     126         return False
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/backend_bases.py:1672, in _allow_interrupt(prepare_notifier, handle_sigint)
#    1670 signal.signal(signal.SIGINT, old_sigint_handler)
#    1671 if handler_args is not None:
# -> 1672     old_sigint_handler(*handler_args)
#
# KeyboardInterrupt:

# %%
# 买卖demo

# %%
# -------- 1) A股佣金模型：佣金 + 卖出印花税(+可选过户费)，含最低佣金 5 元) --------
class AShareCommission(bt.CommInfoBase):
    params = (
        ('commission', 0.0003),   # 券商佣金，0.03%
        ('stamp_duty', 0.0005),   # 印花税，仅卖出收取 0.05%
        ('min_commission', 5.0),  # 单笔最低佣金 5 元（只作用于券商佣金部分）
        ('transfer_fee', 0.0),    # 过户费，可选：上证常见 0.00002，深证为 0。按成交额比例
        ('stocklike', True),
        ('commtype', bt.CommInfoBase.COMM_PERC),
    )

    def _getcommission(self, size, price, pseudoexec):
        # 成交额
        value = abs(size) * price

        # 券商佣金（含最低 5 元）
        broker_comm = max(value * self.p.commission, self.p.min_commission) if value > 0 else 0.0

        # 卖出印花税（仅卖出收）
        stamp = value * self.p.stamp_duty if size < 0 else 0.0

        # 过户费（买卖双向，按需要设置）
        transfer = value * self.p.transfer_fee if self.p.transfer_fee > 0 else 0.0

        return broker_comm + stamp + transfer


# -------- 2) A股下单手数：买入按 100 股整数倍，卖出不限 --------
class AShareSizer(bt.Sizer):
    params = (
        ('lot_size', 100),   # 一手=100股
        ('cash_keep', 0.00), # 预留现金比例（避免满仓导致佣金不足等）
    )

    def _getsizing(self, comminfo, cash, data, isbuy):
        # 决定下单数量
        price = data.close[0]

        if isbuy:
            # 可用预算（预留一点现金）
            budget = cash * (1 - self.p.cash_keep)
            if price <= 0:
                return 0
            # 以手为单位向下取整，再转回股数
            lots = int((budget / price) // self.p.lot_size)
            shares = lots * self.p.lot_size
            return max(shares, 0)
        else:
            # 卖出：返回当前持仓全部股数（A股允许非100倍数卖出）
            pos = self.broker.getposition(data)
            return int(pos.size)


# -------- 3) T+1 示例策略：当日买入，次日才能卖出 --------
class T1ExampleStrategy(bt.Strategy):
    params = dict(
        pfast=10, pslow=20,
    )

    def __init__(self):
        self.sma_fast = bt.ind.SMA(self.data.close, period=self.p.pfast)
        self.sma_slow = bt.ind.SMA(self.data.close, period=self.p.pslow)

        # 记录最近一次“买入完成”的交易日（用于T+1）
        self.last_buy_date = None

    def notify_order(self, order):
        if order.status in [order.Completed]:
            odt = bt.num2date(order.executed.dt).date()
            if order.isbuy():
                # 记录买入完成的日期
                self.last_buy_date = odt

    def can_sell_today(self):
        """T+1：如果今天与最近买入完成是同一天，则不能卖出。"""
        if self.position.size <= 0:
            return False  # 没有持仓无需卖
        if self.last_buy_date is None:
            return True   # 没买过，自由卖
        today = self.data.datetime.date(0)
        return self.last_buy_date < today  # 只有过了一天才可卖

    def next(self):
        # 简单金叉买、死叉卖（演示），加上 T+1 约束
        if not self.position:
            if bt.ind.CrossOver(self.sma_fast, self.sma_slow)[0] > 0:
                self.buy()  # 具体买入数量由 sizer 控制成 100 的整数倍
        else:
            # 死叉出现且满足T+1才卖
            if bt.ind.CrossOver(self.sma_fast, self.sma_slow)[0] < 0 and self.can_sell_today():
                self.sell()


    return results

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders
        self.order = None

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

        elif order.status in [order.Canceled]:
            self.log('Order Canceled')
        elif order.status in [order.Margin]:
            self.log('Order Margin')
        elif order.status in [order.Rejected]:
            self.log('Order Rejected')

        # Write down: no pending order
        self.order = None

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] < self.dataclose[-1]:
                    # current close less than previous close

                    if self.dataclose[-1] < self.dataclose[-2]:
                        # previous close less than the previous close

                        # BUY, BUY, BUY!!! (with default parameters)
                        self.log('BUY CREATE, %.2f' % self.dataclose[0])

                        # Keep track of the created order to avoid a 2nd order
                        self.order = self.buy()

        else:

            # Already in the market ... we might sell
            if len(self) >= (self.bar_executed + 5):
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()

# %%
# 初始化 交易
cerebro = bt.Cerebro()
# 设置初始资金
cerebro.broker.setcash(10000000.0)
cerebro.broker.getcash() # 获取当前可用资金

# 加入A股佣金模型（可按需调整参数）
comminfo = AShareCommission(
    commission=0.0003,      # 券商佣金 0.03%
    stamp_duty=0.0005,      # 卖出印花税 0.05%
    min_commission=5.0,     # 最低佣金 5 元
    transfer_fee=0.0        # 如需上证过户费可设为0.00002
)
cerebro.broker.addcommissioninfo(comminfo)

# A股手数控制（买入 100 股的整数倍）
cerebro.addsizer(AShareSizer, lot_size=100, cash_keep=0.8)

# 通过调用 brokers 的 set_slippage_perc 方法设置百分比滑点
cerebro.broker.set_slippage_perc(perc=0.0001)



# data_ts_600519 = TS_Data(dataname=df_ts600519, fromdate=datetime.datetime(2010,9,1),
#                 todate=datetime.datetime(2010,12,30), nullvalue = None)
# data_ts_000001 = TS_Data(dataname=df_ts000001, fromdate=datetime.datetime(2010,9,1),
#                 todate=datetime.datetime(2010,12,30), nullvalue = None)

data_sql1 = TS_Data(dataname=df_sql1, fromdate=datetime.datetime(2025,1,1),todate=datetime.datetime(2025,8,8))
data_sql2 = TS_Data(dataname=df_sql2, fromdate=datetime.datetime(2025,1,1),todate=datetime.datetime(2025,8,8))
cerebro.adddata(data_sql1, name='000001')
# cerebro.adddata(data_sql2, name='002594')

# %%
cerebro.addstrategy(TestStrategy)
cerebro.run()
# Out:
# 2025-01-02, Close, 11.43
# 2025-01-02, BUY CREATE, 11.43
# 2025-01-03, BUY EXECUTED, 11.44
# 2025-01-03, Close, 11.38
# 2025-01-06, Close, 11.44
# 2025-01-07, Close, 11.51
# 2025-01-08, Close, 11.50
# 2025-01-09, Close, 11.40
# 2025-01-10, Close, 11.30
# 2025-01-10, SELL CREATE, 11.30
# 2025-01-13, SELL EXECUTED, 11.25
# 2025-01-13, Close, 11.20
# 2025-01-13, BUY CREATE, 11.20
# 2025-01-14, BUY EXECUTED, 11.20
# 2025-01-14, Close, 11.38
# 2025-01-15, Close, 11.48
# 2025-01-16, Close, 11.57
# 2025-01-17, Close, 11.45
