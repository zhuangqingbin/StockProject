# %% [markdown]
# # existing table preview
#
# Use this notebook to inspect current tables and preview sample rows from the maintained MySQL database.

# %%
from pathlib import Path
import sys

if ".venv-stock-data" not in sys.executable:
    raise RuntimeError(
        "Wrong Jupyter kernel. Restart the notebook with the project `Python 3` kernel."
    )

repo_root = Path.cwd()
while repo_root.name != "StockProject" and repo_root.parent != repo_root:
    repo_root = repo_root.parent

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
from sqlalchemy import inspect

from apps.stock_data_platform.common.database_runtime import get_engine
from apps.stock_data_platform.notebooks.notebook_support import preview_table

engine = get_engine()
sorted(inspect(engine).get_table_names())[:20]

# %%
preview_table("daily_kline", limit=20)
