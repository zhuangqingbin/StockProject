# %% [markdown]
# # stock_data_platform job catalog
#
# Use this notebook to inspect the current maintained fetch jobs and their write targets.

# %%
from pathlib import Path
import sys

if ".venv-stock-data" not in sys.executable:
    raise RuntimeError(
        "Wrong Jupyter kernel. Restart the notebook with the project `Python 3` kernel."
    )

repo_root = Path.cwd()
while repo_root.name != "StockProject" and repo_root.parent != repo_root:
    repo_root = repo_root.parent

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
import pandas as pd
from apps.stock_data_platform.notebooks.notebook_support import list_job_catalog

pd.set_option("display.max_columns", None)
list_job_catalog()
